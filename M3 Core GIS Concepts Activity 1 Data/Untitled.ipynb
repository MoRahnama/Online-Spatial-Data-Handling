# %%
def testlib_install(libname):
    try:
        import libname
    except ImportError as e:
        pass # module doesn't exist, deal with it.

# %%
# !pip install --upgrade Fiona
# Out:
# Requirement already satisfied: Fiona in c:\users\mohammadali\appdata\roaming\python\python39\site-packages (1.8.21)
# Collecting Fiona
#   Using cached Fiona-1.9.1-cp39-cp39-win_amd64.whl (22.0 MB)
# Requirement already satisfied: attrs>=19.2.0 in c:\programdata\anaconda3\lib\site-packages (from Fiona) (21.4.0)
# Requirement already satisfied: click~=8.0 in c:\programdata\anaconda3\lib\site-packages (from Fiona) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in c:\programdata\anaconda3\lib\site-packages (from Fiona) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\programdata\anaconda3\lib\site-packages (from Fiona) (0.7.2)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from Fiona) (67.4.0)
# Requirement already satisfied: munch>=2.3.2 in c:\programdata\anaconda3\lib\site-packages (from Fiona) (2.5.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from Fiona) (2022.9.14)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click~=8.0->Fiona) (0.4.5)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from munch>=2.3.2->Fiona) (1.16.0)
# Installing collected packages: Fiona
#   Attempting uninstall: Fiona
#     Found existing installation: Fiona 1.8.21
#     Uninstalling Fiona-1.8.21:
#       Successfully uninstalled Fiona-1.8.21
# Successfully installed Fiona-1.9.1

# %%
# !pip install spyder
# Out:
# Requirement already satisfied: spyder in c:\programdata\anaconda3\lib\site-packages (5.2.2)
# Requirement already satisfied: three-merge>=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from spyder) (0.1.1)
# Requirement already satisfied: nbconvert>=4.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (6.4.4)
# Requirement already satisfied: pylint>=2.5.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (2.14.5)
# Requirement already satisfied: watchdog>=0.10.3 in c:\programdata\anaconda3\lib\site-packages (from spyder) (2.1.6)
# Requirement already satisfied: cookiecutter>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (1.7.3)
# Requirement already satisfied: qtconsole<5.3.0,>=5.2.1 in c:\programdata\anaconda3\lib\site-packages (from spyder) (5.2.2)
# Requirement already satisfied: textdistance>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (4.2.1)
# Requirement already satisfied: jellyfish>=0.7 in c:\programdata\anaconda3\lib\site-packages (from spyder) (0.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (0.8.3)
# Requirement already satisfied: jsonschema>=3.2.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (4.16.0)
# Collecting pyqt5<5.13
#   Downloading PyQt5-5.12.3-5.12.10-cp35.cp36.cp37.cp38.cp39-none-win_amd64.whl (51.4 MB)
#      ---------------------------------------- 51.4/51.4 MB 9.1 MB/s eta 0:00:00
# Collecting pyqtwebengine<5.13
#   Downloading PyQtWebEngine-5.12.1-5.12.10-cp35.cp36.cp37.cp38.cp39-none-win_amd64.whl (49.7 MB)
#      --------------------------------------- 49.7/49.7 MB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: pyzmq>=17 in c:\programdata\anaconda3\lib\site-packages (from spyder) (23.2.0)
# Requirement already satisfied: spyder-kernels<2.3.0,>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from spyder) (2.2.1)
# Requirement already satisfied: numpydoc>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (1.4.0)
# Requirement already satisfied: pyls-spyder>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (0.4.0)
# Requirement already satisfied: rtree>=0.9.7 in c:\programdata\anaconda3\lib\site-packages (from spyder) (1.0.0)
# Requirement already satisfied: pexpect>=4.4.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (4.8.0)
# Requirement already satisfied: pickleshare>=0.4 in c:\programdata\anaconda3\lib\site-packages (from spyder) (0.7.5)
# Requirement already satisfied: intervaltree>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from spyder) (3.1.0)
# Requirement already satisfied: keyring>=17.0.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (23.4.0)
# Requirement already satisfied: chardet>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (4.0.0)
# Requirement already satisfied: python-lsp-server[all]<1.4.0,>=1.3.2 in c:\programdata\anaconda3\lib\site-packages (from spyder) (1.3.3)
# Requirement already satisfied: pygments>=2.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (2.11.2)
# Requirement already satisfied: psutil>=5.3 in c:\programdata\anaconda3\lib\site-packages (from spyder) (5.9.0)
# Requirement already satisfied: paramiko>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (2.8.1)
# Requirement already satisfied: sphinx>=0.6.6 in c:\programdata\anaconda3\lib\site-packages (from spyder) (5.0.2)
# Requirement already satisfied: qdarkstyle==3.0.2 in c:\programdata\anaconda3\lib\site-packages (from spyder) (3.0.2)
# Requirement already satisfied: setuptools>=49.6.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (67.4.0)
# Requirement already satisfied: qstylizer>=0.1.10 in c:\programdata\anaconda3\lib\site-packages (from spyder) (0.1.10)
# Requirement already satisfied: diff-match-patch>=20181111 in c:\programdata\anaconda3\lib\site-packages (from spyder) (20200713)
# Requirement already satisfied: cloudpickle>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (2.0.0)
# Requirement already satisfied: atomicwrites>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (1.4.0)
# Requirement already satisfied: ipython<8.0.0,>=7.6.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (7.31.1)
# Requirement already satisfied: jedi<0.19.0,>=0.17.2 in c:\programdata\anaconda3\lib\site-packages (from spyder) (0.18.1)
# Requirement already satisfied: qtawesome>=1.0.2 in c:\programdata\anaconda3\lib\site-packages (from spyder) (1.0.3)
# Requirement already satisfied: python-lsp-black>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (1.0.0)
# Requirement already satisfied: qtpy>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from spyder) (2.2.0)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in c:\programdata\anaconda3\lib\site-packages (from cookiecutter>=1.6.0->spyder) (2.11.3)
# Requirement already satisfied: poyo>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from cookiecutter>=1.6.0->spyder) (0.5.0)
# Requirement already satisfied: six>=1.10 in c:\programdata\anaconda3\lib\site-packages (from cookiecutter>=1.6.0->spyder) (1.16.0)
# Requirement already satisfied: jinja2-time>=0.2.0 in c:\programdata\anaconda3\lib\site-packages (from cookiecutter>=1.6.0->spyder) (0.2.0)
# Requirement already satisfied: click>=7.0 in c:\programdata\anaconda3\lib\site-packages (from cookiecutter>=1.6.0->spyder) (8.0.4)
# Requirement already satisfied: binaryornot>=0.4.4 in c:\programdata\anaconda3\lib\site-packages (from cookiecutter>=1.6.0->spyder) (0.4.4)
# Requirement already satisfied: requests>=2.23.0 in c:\programdata\anaconda3\lib\site-packages (from cookiecutter>=1.6.0->spyder) (2.28.1)
# Requirement already satisfied: python-slugify>=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from cookiecutter>=1.6.0->spyder) (5.0.2)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in c:\programdata\anaconda3\lib\site-packages (from intervaltree>=3.0.2->spyder) (2.4.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython<8.0.0,>=7.6.0->spyder) (0.4.5)
# Requirement already satisfied: matplotlib-inline in c:\programdata\anaconda3\lib\site-packages (from ipython<8.0.0,>=7.6.0->spyder) (0.1.6)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython<8.0.0,>=7.6.0->spyder) (5.1.1)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython<8.0.0,>=7.6.0->spyder) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipython<8.0.0,>=7.6.0->spyder) (3.0.20)
# Requirement already satisfied: traitlets>=4.2 in c:\programdata\anaconda3\lib\site-packages (from ipython<8.0.0,>=7.6.0->spyder) (5.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.2.0->spyder) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.2.0->spyder) (21.4.0)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\programdata\anaconda3\lib\site-packages (from keyring>=17.0.0->spyder) (4.11.3)
# Requirement already satisfied: pywin32-ctypes!=0.1.0,!=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from keyring>=17.0.0->spyder) (0.2.0)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=4.0->spyder) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=4.0->spyder) (4.11.1)
# Requirement already satisfied: bleach in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=4.0->spyder) (4.1.0)
# Requirement already satisfied: testpath in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=4.0->spyder) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=4.0->spyder) (0.8.4)
# Requirement already satisfied: nbformat>=4.4 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=4.0->spyder) (5.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=4.0->spyder) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=4.0->spyder) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=4.0->spyder) (0.5.13)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=4.0->spyder) (0.4)
# Requirement already satisfied: jupyter-core in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=4.0->spyder) (4.11.1)
# Requirement already satisfied: cryptography>=2.5 in c:\programdata\anaconda3\lib\site-packages (from paramiko>=2.4.0->spyder) (37.0.1)
# Requirement already satisfied: pynacl>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from paramiko>=2.4.0->spyder) (1.5.0)
# Requirement already satisfied: bcrypt>=3.1.3 in c:\programdata\anaconda3\lib\site-packages (from paramiko>=2.4.0->spyder) (3.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in c:\programdata\anaconda3\lib\site-packages (from pexpect>=4.4.0->spyder) (0.7.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\programdata\anaconda3\lib\site-packages (from pylint>=2.5.0->spyder) (4.3.0)
# Requirement already satisfied: isort<6,>=4.2.5 in c:\programdata\anaconda3\lib\site-packages (from pylint>=2.5.0->spyder) (5.9.3)
# Requirement already satisfied: platformdirs>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from pylint>=2.5.0->spyder) (2.5.2)
# Requirement already satisfied: astroid<=2.12.0-dev0,>=2.11.6 in c:\programdata\anaconda3\lib\site-packages (from pylint>=2.5.0->spyder) (2.11.7)
# Requirement already satisfied: tomlkit>=0.10.1 in c:\programdata\anaconda3\lib\site-packages (from pylint>=2.5.0->spyder) (0.11.1)
# Requirement already satisfied: tomli>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from pylint>=2.5.0->spyder) (2.0.1)
# Requirement already satisfied: mccabe<0.8,>=0.6 in c:\programdata\anaconda3\lib\site-packages (from pylint>=2.5.0->spyder) (0.6.1)
# Requirement already satisfied: dill>=0.2 in c:\programdata\anaconda3\lib\site-packages (from pylint>=2.5.0->spyder) (0.3.4)
# Requirement already satisfied: PyQt5_sip<13,>=4.19.14 in c:\programdata\anaconda3\lib\site-packages (from pyqt5<5.13->spyder) (12.11.1)
# Requirement already satisfied: toml in c:\programdata\anaconda3\lib\site-packages (from python-lsp-black>=1.0.0->spyder) (0.10.2)
# Requirement already satisfied: black>=19.3b0 in c:\programdata\anaconda3\lib\site-packages (from python-lsp-black>=1.0.0->spyder) (22.6.0)
# Requirement already satisfied: ujson>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from python-lsp-server[all]<1.4.0,>=1.3.2->spyder) (5.4.0)
# Requirement already satisfied: python-lsp-jsonrpc>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from python-lsp-server[all]<1.4.0,>=1.3.2->spyder) (1.0.0)
# Requirement already satisfied: pluggy in c:\programdata\anaconda3\lib\site-packages (from python-lsp-server[all]<1.4.0,>=1.3.2->spyder) (1.0.0)
# Requirement already satisfied: pycodestyle<2.9.0,>=2.8.0 in c:\programdata\anaconda3\lib\site-packages (from python-lsp-server[all]<1.4.0,>=1.3.2->spyder) (2.8.0)
# Requirement already satisfied: pyflakes<2.5.0,>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from python-lsp-server[all]<1.4.0,>=1.3.2->spyder) (2.4.0)
# Requirement already satisfied: pydocstyle>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from python-lsp-server[all]<1.4.0,>=1.3.2->spyder) (6.1.1)
# Requirement already satisfied: flake8<4.1.0,>=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from python-lsp-server[all]<1.4.0,>=1.3.2->spyder) (4.0.1)
# Requirement already satisfied: rope>=0.10.5 in c:\programdata\anaconda3\lib\site-packages (from python-lsp-server[all]<1.4.0,>=1.3.2->spyder) (0.22.0)
# Requirement already satisfied: autopep8<1.7.0,>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from python-lsp-server[all]<1.4.0,>=1.3.2->spyder) (1.6.0)
# Requirement already satisfied: yapf in c:\programdata\anaconda3\lib\site-packages (from python-lsp-server[all]<1.4.0,>=1.3.2->spyder) (0.31.0)
# Requirement already satisfied: tinycss<1,>=0.4 in c:\programdata\anaconda3\lib\site-packages (from qstylizer>=0.1.10->spyder) (0.4)
# Requirement already satisfied: inflection<1,>0.3.0 in c:\programdata\anaconda3\lib\site-packages (from qstylizer>=0.1.10->spyder) (0.5.1)
# Requirement already satisfied: ipython-genutils in c:\programdata\anaconda3\lib\site-packages (from qtconsole<5.3.0,>=5.2.1->spyder) (0.2.0)
# Requirement already satisfied: jupyter-client>=4.1 in c:\programdata\anaconda3\lib\site-packages (from qtconsole<5.3.0,>=5.2.1->spyder) (7.3.4)
# Requirement already satisfied: ipykernel>=4.1 in c:\programdata\anaconda3\lib\site-packages (from qtconsole<5.3.0,>=5.2.1->spyder) (6.15.2)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from qtpy>=1.5.0->spyder) (21.3)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\programdata\anaconda3\lib\site-packages (from sphinx>=0.6.6->spyder) (1.0.1)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\programdata\anaconda3\lib\site-packages (from sphinx>=0.6.6->spyder) (1.0.2)
# Requirement already satisfied: snowballstemmer>=1.1 in c:\programdata\anaconda3\lib\site-packages (from sphinx>=0.6.6->spyder) (2.2.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\programdata\anaconda3\lib\site-packages (from sphinx>=0.6.6->spyder) (0.7.12)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from sphinx>=0.6.6->spyder) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in c:\programdata\anaconda3\lib\site-packages (from sphinx>=0.6.6->spyder) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\programdata\anaconda3\lib\site-packages (from sphinx>=0.6.6->spyder) (1.0.3)
# Requirement already satisfied: docutils<0.19,>=0.14 in c:\programdata\anaconda3\lib\site-packages (from sphinx>=0.6.6->spyder) (0.18.1)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\programdata\anaconda3\lib\site-packages (from sphinx>=0.6.6->spyder) (1.0.2)
# Requirement already satisfied: babel>=1.3 in c:\programdata\anaconda3\lib\site-packages (from sphinx>=0.6.6->spyder) (2.9.1)
# Requirement already satisfied: imagesize in c:\programdata\anaconda3\lib\site-packages (from sphinx>=0.6.6->spyder) (1.4.1)
# Requirement already satisfied: lazy-object-proxy>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from astroid<=2.12.0-dev0,>=2.11.6->pylint>=2.5.0->spyder) (1.6.0)
# Requirement already satisfied: wrapt<2,>=1.11 in c:\programdata\anaconda3\lib\site-packages (from astroid<=2.12.0-dev0,>=2.11.6->pylint>=2.5.0->spyder) (1.14.1)
# Requirement already satisfied: pytz>=2015.7 in c:\programdata\anaconda3\lib\site-packages (from babel>=1.3->sphinx>=0.6.6->spyder) (2022.1)
# Requirement already satisfied: cffi>=1.1 in c:\programdata\anaconda3\lib\site-packages (from bcrypt>=3.1.3->paramiko>=2.4.0->spyder) (1.15.1)
# Requirement already satisfied: pathspec>=0.9.0 in c:\programdata\anaconda3\lib\site-packages (from black>=19.3b0->python-lsp-black>=1.0.0->spyder) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\programdata\anaconda3\lib\site-packages (from black>=19.3b0->python-lsp-black>=1.0.0->spyder) (0.4.3)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=3.6->keyring>=17.0.0->spyder) (3.8.0)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.1->qtconsole<5.3.0,>=5.2.1->spyder) (1.5.5)
# Requirement already satisfied: tornado>=6.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.1->qtconsole<5.3.0,>=5.2.1->spyder) (6.1)
# Requirement already satisfied: debugpy>=1.0 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.1->qtconsole<5.3.0,>=5.2.1->spyder) (1.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from Jinja2<4.0.0,>=2.7->cookiecutter>=1.6.0->spyder) (2.0.1)
# Requirement already satisfied: arrow in c:\programdata\anaconda3\lib\site-packages (from jinja2-time>=0.2.0->cookiecutter>=1.6.0->spyder) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from jupyter-client>=4.1->qtconsole<5.3.0,>=5.2.1->spyder) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core->nbconvert>=4.0->spyder) (302)
# Requirement already satisfied: fastjsonschema in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert>=4.0->spyder) (2.16.2)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0.0,>=7.6.0->spyder) (0.2.5)
# Requirement already satisfied: text-unidecode>=1.3 in c:\programdata\anaconda3\lib\site-packages (from python-slugify>=4.0.0->cookiecutter>=1.6.0->spyder) (1.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter>=1.6.0->spyder) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter>=1.6.0->spyder) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter>=1.6.0->spyder) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter>=1.6.0->spyder) (2.0.4)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=4.0->spyder) (2.3.1)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from bleach->nbconvert>=4.0->spyder) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->qtpy>=1.5.0->spyder) (3.0.9)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4.0->spyder) (2.21)
# Installing collected packages: pyqt5, pyqtwebengine
#   Attempting uninstall: pyqt5
#     Found existing installation: PyQt5 5.15.9
#     Uninstalling PyQt5-5.15.9:
#       Successfully uninstalled PyQt5-5.15.9
#   Attempting uninstall: pyqtwebengine
#     Found existing installation: PyQtWebEngine 5.15.6
#     Uninstalling PyQtWebEngine-5.15.6:
#       Successfully uninstalled PyQtWebEngine-5.15.6
# Successfully installed pyqt5-5.12.3 pyqtwebengine-5.12.1

# %%
package_name = "http"
testlib_install(package_name)

# %%
package_name = "xArray"
testlib_install(package_name)

# %%
package_name = "GDAL"
testlib_install(package_name)

# %%
package_name = "ogr"
testlib_install(package_name)

# %%
package_name = "rasterio"
testlib_install(package_name)

# %%
package_name = "matplotlib"
testlib_install(package_name)

# %%
package_name = "ipyleaflet"
testlib_install(package_name)

# %%
package_name = "folium"
testlib_install(package_name)

# %%
package_name = "owslib"
testlib_install(package_name)

# %%
package_name = "tabulate"
testlib_install(package_name)

# %%
package_name = "pysal"
testlib_install(package_name)

# %%
package_name = "seaborn"
testlib_install(package_name)

# %%
package_name = "sklearn"
testlib_install(package_name)

# %%
pip list # to list all the libraries you have installed.
# Out:
# Package                       Version
# ----------------------------- --------------------
# affine                        2.4.0
# alabaster                     0.7.12
# anaconda-client               1.11.0
# anaconda-navigator            2.3.1
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.11.7
# astropy                       5.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# bitarray                      2.5.1
# bkcharts                      0.2
# black                         22.6.0
# bleach                        4.1.0
# bokeh                         2.4.3
# boto3                         1.24.28
# botocore                      1.27.28
# Bottleneck                    1.3.5
# branca                        0.6.0
# brotlipy                      0.7.0
# certifi                       2022.9.14
# cffi                          1.15.1
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# click-plugins                 1.1.1
# cligj                         0.7.2
# cloudpickle                   2.0.0
# clyent                        1.2.2
# colorama                      0.4.5
# colorcet                      3.0.0
# comtypes                      1.1.10
# conda                         23.1.0
# conda-build                   3.22.0
# conda-content-trust           0.1.3
# conda-pack                    0.6.0
# conda-package-handling        2.0.2
# conda_package_streaming       0.7.0
# conda-repo-cli                1.0.27
# conda-token                   0.4.0
# conda-verify                  3.4.2
# constantly                    15.1.0
# cookiecutter                  1.7.3
# cryptography                  37.0.1
# cssselect                     1.1.0
# cycler                        0.11.0
# Cython                        0.29.32
# cytoolz                       0.11.0
# daal4py                       2021.6.0
# dask                          2022.7.0
# datashader                    0.14.1
# datashape                     0.5.4
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# dill                          0.3.4
# distributed                   2022.7.0
# docutils                      0.18.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# fastjsonschema                2.16.2
# filelock                      3.6.0
# Fiona                         1.9.1
# flake8                        4.0.1
# Flask                         1.1.2
# folium                        0.14.0
# fonttools                     4.25.0
# fsspec                        2022.7.1
# future                        0.18.2
# GDAL                          3.4.3
# gensim                        4.1.2
# geopandas                     0.12.2
# gitdb                         4.0.10
# GitPython                     3.1.31
# glob2                         0.7
# greenlet                      1.1.1
# h5py                          3.7.0
# HeapDict                      1.0.1
# holoviews                     1.15.0
# hvplot                        0.8.0
# hyperlink                     21.0.0
# idna                          3.3
# imagecodecs                   2021.8.26
# imageio                       2.19.3
# imagesize                     1.4.1
# importlib-metadata            4.11.3
# incremental                   21.3.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.5
# intervaltree                  3.1.0
# ipykernel                     6.15.2
# ipyleaflet                    0.17.2
# ipython                       7.31.1
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jdcal                         1.4.1
# jedi                          0.18.1
# jellyfish                     0.9.0
# Jinja2                        2.11.3
# jinja2-time                   0.2.0
# jmespath                      0.10.0
# joblib                        1.1.0
# json5                         0.9.6
# jsonlines                     1.2.0
# jsonschema                    4.16.0
# jupyter                       1.0.0
# jupyter_client                7.3.4
# jupyter-console               6.4.3
# jupyter_core                  4.11.1
# jupyter-server                1.18.1
# jupyterlab                    3.4.4
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.10.3
# jupyterlab-widgets            1.0.0
# keyring                       23.4.0
# kiwisolver                    1.4.2
# lazy-object-proxy             1.6.0
# libarchive-c                  2.9
# llvmlite                      0.38.0
# locket                        1.0.0
# lxml                          4.9.1
# lz4                           3.1.3
# mapclassify                   2.5.0
# Markdown                      3.3.4
# MarkupSafe                    2.0.1
# matplotlib                    3.5.2
# matplotlib-inline             0.1.6
# mccabe                        0.6.1
# menuinst                      1.4.19
# mistune                       0.8.4
# mkl-fft                       1.3.1
# mkl-random                    1.2.2
# mkl-service                   2.4.0
# mock                          4.0.3
# mpmath                        1.2.1
# msgpack                       1.0.3
# multipledispatch              0.6.0
# munch                         2.5.0
# munkres                       1.1.4
# mypy-extensions               0.4.3
# navigator-updater             0.3.0
# nbclassic                     0.3.5
# nbclient                      0.5.13
# nbconvert                     6.4.4
# nbformat                      5.5.0
# nest-asyncio                  1.5.5
# networkx                      2.8.4
# nltk                          3.7
# nose                          1.3.7
# notebook                      6.4.12
# numba                         0.55.1
# numexpr                       2.8.3
# numpy                         1.21.5
# numpydoc                      1.4.0
# ogr                           0.43.0
# olefile                       0.46
# opencv-contrib-python         4.7.0.72
# openpyxl                      3.0.10
# OWSLib                        0.28.1
# packaging                     21.3
# pandas                        1.4.4
# pandocfilters                 1.5.0
# panel                         0.13.1
# param                         1.12.0
# paramiko                      2.8.1
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.2.0
# pathlib                       1.0.1
# pathspec                      0.9.0
# patsy                         0.5.2
# pep8                          1.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.2.0
# pip                           22.2.2
# pkginfo                       1.8.2
# platformdirs                  2.5.2
# plotly                        5.9.0
# pluggy                        1.0.0
# poyo                          0.5.0
# prometheus-client             0.14.1
# prompt-toolkit                3.0.20
# Protego                       0.1.16
# psutil                        5.9.0
# ptyprocess                    0.7.0
# PuLP                          2.7.0
# py                            1.11.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.8.0
# pycosat                       0.6.3
# pycparser                     2.21
# pyct                          0.4.8
# pycurl                        7.45.1
# PyDispatcher                  2.0.5
# pydocstyle                    6.1.1
# pyerfa                        2.0.0
# pyflakes                      2.4.0
# pygeos                        0.14
# PyGithub                      1.58.0
# Pygments                      2.11.2
# PyHamcrest                    2.0.2
# PyJWT                         2.4.0
# pylint                        2.14.5
# pyls-spyder                   0.4.0
# PyNaCl                        1.5.0
# pyodbc                        4.0.34
# pyOpenSSL                     22.0.0
# pyparsing                     3.0.9
# pyproj                        3.4.1
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pytest                        7.1.2
# python-dateutil               2.8.2
# python-gitlab                 3.13.0
# python-lsp-black              1.0.0
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.3.3
# python-slugify                5.0.2
# python-snappy                 0.6.0
# pytz                          2022.1
# pyviz-comms                   2.0.2
# PyWavelets                    1.3.0
# pywin32                       302
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.2
# PyYAML                        6.0
# pyzmq                         23.2.0
# QDarkStyle                    3.0.2
# qstylizer                     0.1.10
# QtAwesome                     1.0.3
# qtconsole                     5.2.2
# QtPy                          2.2.0
# queuelib                      1.5.0
# rasterio                      1.3.6
# regex                         2022.7.9
# requests                      2.28.1
# requests-file                 1.5.1
# requests-toolbelt             0.10.1
# rope                          0.22.0
# Rtree                         0.9.7
# ruamel.yaml                   0.17.21
# ruamel.yaml.clib              0.2.6
# ruamel-yaml-conda             0.15.100
# s3transfer                    0.6.0
# scikit-image                  0.19.2
# scikit-learn                  1.0.2
# scikit-learn-intelex          2021.20221004.171935
# scipy                         1.9.1
# Scrapy                        2.6.2
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# service-identity              18.1.0
# setuptools                    67.4.0
# shapely                       2.0.1
# simplejson                    3.18.3
# sip                           4.19.13
# six                           1.16.0
# sklearn                       0.0.post1
# smart-open                    5.2.1
# smmap                         5.0.0
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# snuggs                        1.4.7
# sortedcollections             2.1.0
# sortedcontainers              2.4.0
# soupsieve                     2.3.1
# Sphinx                        5.0.2
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.2.2
# spyder-kernels                2.2.1
# SQLAlchemy                    1.4.39
# statsmodels                   0.13.2
# sympy                         1.10.1
# tables                        3.6.1
# tabulate                      0.8.10
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.0.1
# terminado                     0.13.1
# testpath                      0.6.0
# text-unidecode                1.3
# textdistance                  4.2.1
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tifffile                      2021.7.2
# tinycss                       0.4
# tldextract                    3.2.0
# toml                          0.10.2
# tomli                         2.0.1
# tomlkit                       0.11.1
# toolz                         0.11.2
# tornado                       6.1
# tqdm                          4.64.1
# traitlets                     5.1.1
# traittypes                    0.2.1
# Twisted                       22.2.0
# twisted-iocpsupport           1.0.2
# typing_extensions             4.3.0
# ujson                         5.4.0
# Unidecode                     1.2.0
# urllib3                       1.26.11
# w3lib                         1.21.0
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# Werkzeug                      2.0.3
# wheel                         0.37.1
# widgetsnbextension            3.5.2
# win-inet-pton                 1.1.0
# win-unicode-console           0.5
# wincertstore                  0.2
# wrapt                         1.14.1
# xarray                        0.20.1
# xlrd                          2.0.1
# XlsxWriter                    3.0.3
# xlwings                       0.27.15
# xyzservices                   2023.2.0
# yapf                          0.31.0
# zict                          2.1.0
# zipp                          3.8.0
# zope.interface                5.4.0
# zstandard                     0.19.0
# Note: you may need to restart the kernel to use updated packages.
